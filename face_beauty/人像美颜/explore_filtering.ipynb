# %% [markdown]
# ## Filtering
#
# ### What is it ?
# - Filtering is perhaps the most fundamental operation of image processing and computer vision.
# - 对点附近的区域计算, 得到的结果替换该点
# - 同时考虑: 像素点的空域信息（domain）和值域信息（range）
#
#
# ###  ref
# - [Bilateral Filtering for Gray and Color Images](https://homepages.inf.ed.ac.uk/rbf/CVonline/LOCAL_COPIES/MANDUCHI1/Bilateral_Filtering.html)
# - [A Gentle Introduction to Bilateral Filtering and its Applications](https://people.csail.mit.edu/sparis/bf_course/course_notes.pdf)

# %%
import cv2
from PIL import Image
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### 高斯模糊

# %%
# icecream_img = Image.open('./1.jpg')
# icecream_img  # .show()
icecream_img = cv2.imread('./1.jpg')
plt.imshow(cv2.cvtColor(icecream_img, cv2.COLOR_BGR2RGB))
plt.title("冰激凌")
plt.show()

# %%
girl_img = Image.open('./3.jpg')
girl_img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=337x600>

# %%
cv2.imread?

# %%
ImreadModes
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [11], line 1
# ----> 1 cv2.ImreadModes
#
# AttributeError: module 'cv2' has no attribute 'ImreadModes'
